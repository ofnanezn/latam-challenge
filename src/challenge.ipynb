# %% [markdown]
# En este archivo puedes escribir lo que estimes conveniente. Te recomendamos detallar tu solución y todas las suposiciones que estás considerando. Aquí puedes ejecutar las funciones que definiste en los otros archivos de la carpeta src, medir el tiempo, memoria, etc.

# %%
# %load_ext memory_profiler
file_path = "farmers-protest-tweets-2021-2-4.json"

# %% [markdown]
# # Question 1

# %% [markdown]
# ## Question 1 - Time optimized
# For the time optimized version, I'm using PyArrow to load json lines file efficiently. I'm doing an assumption, that is assigning a fixed schema to Json file.

# %%
# Assuming Jupyter Notebook is launched from the repository root directory
from src.q1_time import q1_time

# %%
print(q1_time(file_path=f"src/{file_path}"))
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'), (datetime.date(2021, 2, 13), 'MaanDee08215437'), (datetime.date(2021, 2, 17), 'RaaJVinderkaur'), (datetime.date(2021, 2, 16), 'jot__b'), (datetime.date(2021, 2, 14), 'rebelpacifist'), (datetime.date(2021, 2, 18), 'neetuanjle_nitu'), (datetime.date(2021, 2, 15), 'jot__b'), (datetime.date(2021, 2, 20), 'MangalJ23056160'), (datetime.date(2021, 2, 23), 'Surrypuria'), (datetime.date(2021, 2, 19), 'Preetm91')]

# %%
# %timeit q1_time(file_path=f"src/{file_path}")
# Out:
# 958 ms ± 20.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q1_time(file_path=f"src/{file_path}")
# Out:
# peak memory: 762.39 MiB, increment: 3.50 MiB

# %% [markdown]
# ## Question 1 - Memory optimized
# In order to improve memory utilization, I loaded file in chunks, which can increase processing time, but it only loads file in chunks which can decrease memory peaks

# %%
from src.q1_memory import q1_memory

# %%
print(q1_memory(file_path=f"src/{file_path}"))
# Out:
# [(datetime.date(2021, 2, 12), 'Aman96442728'), (datetime.date(2021, 2, 13), 'FarmerP46551857'), (datetime.date(2021, 2, 17), '13Chardikala'), (datetime.date(2021, 2, 16), 'A52475884'), (datetime.date(2021, 2, 14), '1DALBIR'), (datetime.date(2021, 2, 18), 'AFarmersSon1'), (datetime.date(2021, 2, 15), 'Anumanhas11'), (datetime.date(2021, 2, 20), '01Tej'), (datetime.date(2021, 2, 23), '13navreetsingh'), (datetime.date(2021, 2, 19), 'Ambisandhu26')]

# %%
# %timeit q1_memory(file_path=f"src/{file_path}")
# Out:
# 2.28 s ± 104 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q1_memory(file_path=f"src/{file_path}")
# Out:
# peak memory: 494.43 MiB, increment: 0.00 MiB

# %% [markdown]
# # Question 2

# %% [markdown]
# ## Question 2 - Time optimized
# **NOTE:** It was used an emoji library which required to use apply to extract the emojis, but it is not efficient, it can be improved by using some regex to extract emojis from content.

# %%
# Assuming Jupyter Notebook is launched from the repository root directory
from src.q2_time import q2_time

# %%
print(q2_time(file_path=f"src/{file_path}"))
# Out:
# [('🙏', 5049), ('😂', 3072), ('🚜', 2972), ('🌾', 2182), ('🇮🇳', 2086), ('🤣', 1668), ('✊', 1651), ('❤️', 1382), ('🙏🏻', 1317), ('💚', 1040)]

# %%
# %time q2_time(file_path=f"src/{file_path}")
# Out:
# CPU times: user 14.3 s, sys: 157 ms, total: 14.5 s
# Wall time: 12.5 s
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %%
# %memit q2_time(file_path=f"src/{file_path}")
# Out:
# peak memory: 301.81 MiB, increment: 45.89 MiB

# %% [markdown]
# ## Question 2 - Memory optimized

# %%
from src.q2_memory import q2_memory

# %%
print(q2_memory(file_path=f"src/{file_path}"))
# Out:
# [('🙏', 5049), ('😂', 3072), ('🚜', 2972), ('🌾', 2182), ('🇮🇳', 2086), ('🤣', 1668), ('✊', 1651), ('❤️', 1382), ('🙏🏻', 1317), ('💚', 1040)]

# %%
# %time q2_memory(file_path=f"src/{file_path}")
# Out:
# CPU times: user 19.9 s, sys: 159 ms, total: 20.1 s
# Wall time: 18.1 s
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %%
# %memit q2_memory(file_path=f"src/{file_path}")
# Out:
# peak memory: 279.84 MiB, increment: 0.00 MiB

# %% [markdown]
# # Question 3

# %% [markdown]
# ## Question 3 - Time optimized

# %%
from src.q3_time import q3_time

# %%
print(q3_time(file_path=f"src/{file_path}"))
# Out:
# [('narendramodi', 2265), ('Kisanektamorcha', 1840), ('RakeshTikaitBKU', 1644), ('PMOIndia', 1427), ('RahulGandhi', 1146), ('GretaThunberg', 1048), ('RaviSinghKA', 1019), ('rihanna', 986), ('UNHumanRights', 962), ('meenaharris', 926)]

# %%
# %timeit q3_time(file_path=f"src/{file_path}")
# Out:
# 797 ms ± 14.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q3_time(file_path=f"src/{file_path}")
# Out:
# peak memory: 664.64 MiB, increment: 9.74 MiB

# %% [markdown]
# ## Question 3 - Memory optimized

# %%
from src.q3_memory import q3_memory

# %%
print(q3_memory(file_path=f"src/{file_path}"))
